# %% [markdown]
# # Explorotory Data Analysis

# %%
np.loadtxt('matrix.txt')
# Out:
# array([1., 3., 4.])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


dataset = pd.read_csv('iris.csv')

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(dataset.columns)
print(dataset['species'].value_counts())
print(dataset['sepal_width'].mean())
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64
# 3.0540000000000003

# %% [markdown]
# 2-D scatter plot

# %%
dataset.plot(kind = 'scatter' , x = 'sepal_length' , y = 'sepal_width')

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dataset,hue = "species",size = 4).map(plt.scatter,"sepal_length","sepal_width").add_legend()
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# pair plot

# %%
sns.set_style("whitegrid")
sns.pairplot(dataset,hue = "species",size = 3)
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
Unvariate analysis

# %%
sns.set_style('whitegrid')
sns.FacetGrid(dataset,hue = 'species',size = 3).map(sns.distplot,"petal_length").add_legend()
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(dataset,hue = 'species',size = 3).map(sns.distplot,"petal_width").add_legend()
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(dataset,hue = 'species',size = 3).map(sns.distplot,"sepal_length").add_legend()
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(dataset,hue = 'species',size = 3).map(sns.distplot,"sepal_width").add_legend()
# Out:
# /home/clive69/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#from above prob.dsitributions 
'''
petal_length > petal_width >>

'''

# %% [markdown]
# Mean , Variance and Std - dev

# %%
# Out:
# 3.758666666666666

# %%
sns.boxplot(x = 'species' , y = 'petal_length',data = dataset)

# %%
'''
lines - 25,50,75 values 

25% of versicolor and viriginca are same.

wiskers - (range) max and min value

sns uses 1.5 * iqr 25 - 75 quertile 
'''

# %%
violin plot
Boxplot + Prob. Distribution

# %%
sns.violinplot(x = 'species',y = 'petal_length',data = dataset,size = 10)

# %%
Multiviriate plot

# %%
sns.jointplot(x = 'petal_length', y = 'petal_width' ,data = dataset,kind = 'kde')
